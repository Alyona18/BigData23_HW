# %% [markdown]
# Запустите  задачу с использованием локального движка `MRJob` на полном файле:
#
# ![image.png](attachment:image.png)
#
# затем с помощью `hadoop`:
#
# ![image-2.png](attachment:image-2.png)
#
#
# По времени видно, что во втором случае программа отрабатывает быстрее

# %% [markdown]
# Запустите  задачу с использованием локального движка `MRJob` на урезаном файле (50 строк):
#
# ![image.png](attachment:image.png)
#
# затем с помощью `hadoop`:
#
# ![image-2.png](attachment:image-2.png)
#
# В этом случае быстрее отраабатывает MRJob.
#
# Таким образот при небольшом количестве данных теряется преимущество hadoop.
